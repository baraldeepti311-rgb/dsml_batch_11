# %% [markdown]
# (**ASSIGNMENT 1)**

# %%
my_list = input("please enter any sentence: ")
print("uppercase :",my_list.upper())
# Out:
# please enter any sentence: learning programming is interesting
# uppercase : LEARNING PROGRAMMING IS INTERESTING

# %%
my_list1 = input("please enter any sentence: ")
print("lowercase :", my_list1.lower())
# Out:
# please enter any sentence: Learning Programming is Interesting
# lowercase : learning programming is interesting

# %%
my_list2 = input ("please enter any sentence: ")
print("Title :",my_list2.title())
# Out:
# please enter any sentence: i am deepti baral
# Title : I Am Deepti Baral

# %%
my_list3 =input ("Any word: ")
print("Capitalized:", my_list3.capitalize())
# Out:
# Any word: i am from pokhara
# Capitalized: I am from pokhara

# %%
my_list4 = input ("word: ")
print("Strip:", my_list4.strip())
# Out:
# word:       I am Active Learner
# Strip: I am Active Learner

# %%
my_list5 = input ("word: ")
print("Split:",my_list5.split())
# Out:
# word: Let's connect to world
# Split: ["Let's", 'connect', 'to', 'world']

# %%
my_list6 = input ("word: ")
print("Replace:",my_list6.replace("hard","easy"))
# Out:
# word: Python is hard to learn
# Replace: Python is easy to learn

# %%
my_list7 = input("word: ")
print("Find:",my_list7.find("lead"))
print("Find:",my_list7.find("banana"))
# Out:
# word: Small steps lead to success
# Find: 12
# Find: -1

# %%
my_list8 = input("number: ")
print("Count:",my_list8.count("5"))
# Out:
# number: 1,5,7,5,2,5,8,5
# Count: 4

# %%
my_list9  = input("word: ")
print("Join:",my_list9.join("af"))
# Out:
# word: "b","c","d","e"
# Join: a"b","c","d","e"f

# %%
my_list10 = input("word: ")
print("islower():",my_list10.islower())
print("isalnum():",my_list10.isalnum())
# Out:
# word: today is a beautiful day
# islower(): True
# isalnum(): False

# %%
my_list11 = input("word: ")
print("isdigit:",my_list11.isdigit())
# Out:
# word: 123456789
# isdigit: True
